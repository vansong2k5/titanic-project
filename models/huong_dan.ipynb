# %% [markdown]
# ### Pipeline

# %%
model_pipeline = Pipeline(steps=[
    ('feature_engineering', TitanicTransformer()), # Bước của bạn
    ('preprocessing', preprocessor),                # Bước làm sạch/mã hóa
    # ('classifier', RandomForestClassifier(n_estimators=100, random_state=42)) # Model
])

# %% [markdown]
# ### Cách nạp lại model

# %%
# Nạp lại model từ file đã lưu
loaded_model = joblib.load('titanic_svc_model.pkl')

# Dự đoán trực tiếp từ dữ liệu thô (không cần xử lý lại bằng tay)
# Giả sử 'X_new' là dữ liệu mới từ khách hàng
predictions = loaded_model.predict(X_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model_pipeline = Pipeline(steps=[
#       2     ('feature_engineering', TitanicTransformer()), # Bước của bạn
#       3     ('preprocessing', preprocessor),                # Bước làm sạch/mã hóa
#       4     # ('classifier', RandomForestClassifier(n_estimators=100, random_state=42)) # Model
#       5 ])
#
# NameError: name 'Pipeline' is not defined
