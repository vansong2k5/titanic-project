# %% [markdown]
# ### Introduce to Matplotlib

# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# xem các style đồ thị hiện có để dùng
plt.style.available
plt.style.use('seaborn-v0_8-darkgrid')

# %%
plt.plot();

# %%
x = [1,2,3,4]
y= [10,8,6,9]
plt.plot(x,y,color='red');
