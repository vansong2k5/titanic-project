# %% [markdown]
# ### Step 1: Import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 1: Import Data

# %%
df = pd.read_csv("test.csv")
df.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %% [markdown]
# ### Data Overview

# %%
# xem hình dạng của bảng
df.shape
# Out:
# (418, 11)

# %%
# Xem tổng quan từng hàng xem có bị miss data và datatype của nó
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
# print all columns name as list
list_feature = list(df.columns)

# %%
# kiểm tra xem có bao nhiêu hàng
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
# đưa ra static về dataset chỉ return thống kê với số, thêm include ="all" để thêm toàn bộ feature chữ
df.describe(include = "all")
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %% [markdown]
# ### loc and iloc

# %%
# Select rows with multiple conditions and get desire columns 
df.loc[(df.Pclass>2) & (df.PassengerId<900), ['Name', 'Age']]
# Out:
#                                            Name   Age
# 0                              Kelly, Mr. James  34.5
# 1              Wilkes, Mrs. James (Ellen Needs)  47.0
# 3                              Wirz, Mr. Albert  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 5                    Svensson, Mr. Johan Cervin  14.0
# 6                          Connolly, Miss. Kate  30.0

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Dùng để chọn rows theo index
df.iloc[[2]]
# Out:
#    PassengerId  Pclass                       Name   Sex   Age  SibSp  Parch  \
# 2          894       2  Myles, Mr. Thomas Francis  male  62.0      0      0
#
#    Ticket    Fare Cabin Embarked
# 2  240276  9.6875   NaN        Q

# %%
#Dùng để tách bảng
df.iloc[:2,:-1]
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin
# 0      0  330911  7.8292   NaN
# 1      0  363272  7.0000   NaN

# %% [markdown]
# ### Data Manipulation

# %%
# kiểm tra kiểu dữ liệu của cột
df.Cabin.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Apply

# %%
# Ép kiểu và thay thế số lượng lớn kết hợp apply + lambda
df["Cabin"] = df["Cabin"].apply(lambda x: 0 if pd.isna(x) else 1)

# %%
df.Cabin
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Cabin, Length: 418, dtype: int64

# %%
# Create new feature
df["live"] = df.Age -1

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare  Cabin Embarked  live
# 0  34.5      0      0   330911   7.8292      0        Q  33.5
# 1  47.0      1      0   363272   7.0000      0        S  46.0
# 2  62.0      0      0   240276   9.6875      0        Q  61.0
# 3  27.0      0      0   315154   8.6625      0        S  26.0
# 4  22.0      1      1  3101298  12.2875      0        S  21.0

# %%
# Static by feature
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
# count sum of any value in feature
df.Sex.value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
# How many different value in feature
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)
